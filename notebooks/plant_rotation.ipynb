# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from skimage.io import Image
from skimage import data
from skimage import transform as tf

from skimage.io import imread

# %%
leaf = imread('../data/all/platane/platane-1.jpeg')
leaf_max = np.max(leaf.shape[:2])
leaf_base = np.array((300, 200))
leaf_top = np.array((100, 200))
dst = np.array([leaf_base, leaf_top])

expected_base = np.array((250, 400))
expected_top = np.array((250, 100))
src = np.array([expected_base, expected_top])

leaf_center = (leaf_top + leaf_base) / 2

# %%
tform = tf.estimate_transform('similarity', src, dst)
rotated = tf.warp(leaf, tform)

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(8, 3))
plt.gray()

ax1.imshow(leaf)
ax1.plot(base[0], base[1], ".b")
ax1.plot(top[0], top[1], ".r")

ax2.imshow(rotated)
ax2.plot(expected_base[0], expected_base[1], ".b")
ax2.plot(expected_top[0], expected_top[1], ".r")

# %%
leaf_center
# Out:
# array([200, 200])

# %%
leaf.resize?
