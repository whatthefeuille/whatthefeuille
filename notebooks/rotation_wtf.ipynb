# %%
import pylab as pl

from wtf.processing import warp_img
from wtf.processing import get_warped_img_path
from wtf.processing import save_normalized


from skimage.io import imread
from skimage.io import imsave
# Out:
# /usr/local/lib/python2.7/site-packages/nose/plugins/manager.py:418: UserWarning: Module argparse was already imported from /usr/local/Cellar/python/2.7.3/Frameworks/Python.framework/Versions/2.7/lib/python2.7/argparse.pyc, but /usr/local/lib/python2.7/site-packages is being added to sys.path
#   import pkg_resources

# %%
original_path = '/Users/ogrisel/Dropbox/Camera Uploads/2012-11-30 23.13.56.jpg'
normalized_path = '/tmp/normalized.jpeg'
save_normalized(original_path, normalized_path)
normalized = imread(normalized_path)
pl.imshow(normalized)
